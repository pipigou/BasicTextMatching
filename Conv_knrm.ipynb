# %%
import os
import re
import random
import copy
from collections import Counter
try:
    import cPickle as pickle
except ImportError:
    import pickle
import gc
    
from gensim.models import KeyedVectors

import numpy as np
from numpy.random import seed
seed(1000)
from tensorflow.random import set_random_seed
set_random_seed(1000)

import pandas
from pandas import Series, DataFrame

import keras
import keras.backend as K
# from keras.layers import Layer
from keras.engine import Layer
from keras.engine import InputSpec
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Embedding, Conv1D, Concatenate, Flatten, Dropout, Dense, Bidirectional, Activation
from keras.layers import MaxPooling1D, Conv2D, Flatten, Reshape, MaxPooling2D, LSTM, Lambda, Highway, Dot
from keras.models import Model, Sequential
from keras.activations import softmax
from keras.initializers import Constant, RandomNormal, RandomUniform

import tensorflow as tf
import keras.backend.tensorflow_backend as KTF

import matplotlib.pyplot as plt
import seaborn as sns       

from scipy import stats
from scipy.stats import  norm
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline 

#进行配置，使用30%的GPU
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
session = tf.Session(config=config)

# 设置session
KTF.set_session(session )

# %%
# 文件路径
ORIGINAL_FILE_PATH = "../data/original_data/quora_duplicate_questions.tsv"

DATA_ALL_PATH = "../data/all_data.txt"

DATA_TRAIN_PATH = "../data/train.txt"
DATA_VALID_PATH = "../data/valid.txt"
DATA_TEST_PATH = "../data/test.txt"

MAPS_FILE_PATH = "../data/maps.pkl"

# Glove文件
WORD2VEC_PATH = "../data/GoogleNews-vectors-negative300.bin"

# Model Path
MODEL_PATH = "../model/conv_knrm/conv_knrm-01.h5"

# 创建文件夹
(file_path, file_name) = os.path.split(MODEL_PATH)
if not os.path.exists(file_path):
    os.mkdir(file_path)

# %%
def load_dict(dict_path):
    with open(dict_path, 'rb') as fr:
        return pickle.load(fr)
        
def create_maps(dico):
    item2id = dico
    id2item = dict([val, key] for key, val in dico.items())
    return item2id, id2item

def read_file(fpath):
    """
    读取文件，返回
    """
    question1, question2, labels = [], [], []
    with open(fpath, 'r', encoding="utf-8") as fr:
        for line in fr.readlines():
            try:
                q, k, l = line.strip().split('\t')
            except ValueError:
                print(line)
            question1.append(q)
            question2.append(k)
            labels.append(int(l))
            
    return question1, question2, labels

def load_data(fpath, word_to_id, max_length=20):
    """
    载入数据，并将其转化为id表示
    """
    question1, question2, labels = read_file(fpath)
    
    q1_id, q2_id = [], []
    for i in range(len(question1)):
        q1= question1[i].split()
        q2 = question2[i].split()
        q1_id.append([word_to_id[x] for x in q1 if x in word_to_id])
        q2_id.append([word_to_id[x] for x in q2 if x in word_to_id])

    # 使用keras提供的pad_sequences来将文本pad为固定长度
    x1_pad = keras.preprocessing.sequence.pad_sequences(q1_id, max_length, padding="post")
    x2_pad = keras.preprocessing.sequence.pad_sequences(q2_id, max_length, padding="post")
    labels = keras.utils.np_utils.to_categorical(labels)
    
    return x1_pad, x2_pad, labels
    
        
def load_word2vec(embedding_path, word_index, embed_dim=300): 
    """
    载入预训练好的word2vec(Google-News)
    """
    # 载入word2vec词向量
    word2vec_dict = KeyedVectors.load_word2vec_format(embedding_path,binary=True)
    
    embedding_index = dict()
    for word in word2vec_dict.wv.vocab:
        embedding_index[word] = word2vec_dict.word_vec(word)
    print('Load %s word vectors.' % len(embedding_index))
    
    all_embs = np.stack(list(embedding_index.values()))
    # emb_mean, emb_std = all_embs.mean(), all_embs.std()
    emb_mean = np.mean(all_embs, axis=0)
    vocab_size = len(word_index)
    # 初始化权重
    embedding_matrix = np.zeros((vocab_size+1, embed_dim))
    gc.collect()
    # 对权重矩阵进行赋值，未找到时用词向量平均值填充
    for word, i in word_index.items():
        if i < vocab_size + 1:
            embedding_vector = embedding_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
            else:
                embedding_matrix[i] = emb_mean
    del embedding_index
    return embedding_matrix

# %%
dico = load_dict(MAPS_FILE_PATH)
word_index, index_word = create_maps(dico)

# 准备数据
x1_train, x2_train, y_train = load_data(DATA_TRAIN_PATH, word_index)
x1_valid, x2_valid, y_valid = load_data(DATA_VALID_PATH, word_index)
x1_test, x2_test, y_test = load_data(DATA_TEST_PATH, word_index)

embedding_matrix = load_word2vec(WORD2VEC_PATH, word_index)
# Out:
# Load 3000000 word vectors.

# %%
vocab_size = len(dico)

class Settings(object):
    text1_maxlen = 20
    text2_maxlen = 20
    embedding_dim = 300
    vocab_size = vocab_size

    max_ngram = 3
    num_filters = 64
    kernel_num = 64
    sigma = 0.1
    exact_sigma = 0.001
    if_crossmatch = True
    
    dropout_rate = 0.2
    
settings = Settings()

# %%
# 定义网络
def kernel_layer(mu, sigma):
    def kernel(x):
        return K.tf.exp(-0.5 * (x - mu)*(x-mu)/sigma/sigma)
    return Activation(kernel)

query = Input(name='query', shape=(settings.text1_maxlen,))
doc = Input(name='doc', shape=(settings.text2_maxlen,))


embedding = Embedding(settings.vocab_size + 1,
                      settings.embedding_dim,
                      weights=[embedding_matrix],
                      input_length=settings.text1_maxlen,
                      trainable=False)

q_embed = embedding(query)
d_embed = embedding(doc)

convs = []
q_convs = []
d_convs = []
for i in range(settings.max_ngram):
    c = Conv1D(settings.num_filters, i+1, activation="relu", padding="same")
    q_convs.append(c(q_embed))
    d_convs.append(c(d_embed))
    
KM = []

for qi in range(settings.max_ngram):
    for di in range(settings.max_ngram):
        if not settings.if_crossmatch and qi != di:
            print("non cross")
            continue
        q_ngram = q_convs[qi]
        d_ngram = d_convs[di]
        mm = Dot(axes=[2, 2], normalize=True)([q_ngram, d_ngram])
        for i in range(settings.kernel_num):
            mu = 1. / (settings.kernel_num - 1) + (2. * i) /(settings.kernel_num - 1) - 1.0
            sigma = settings.sigma
            if mu > 1.0:
                sigma = settings.exact_sigma
                mu = 1.0
            mm_exp = kernel_layer(mu, sigma)(mm)
            mm_doc_sum = Lambda(lambda x: K.tf.reduce_sum(x,2))(mm_exp)
            mm_log = Activation(K.tf.log1p)(mm_doc_sum)
            mm_sum = Lambda(lambda x: K.tf.reduce_sum(x, 1))(mm_log)
            KM.append(mm_sum)
            
Phi = Lambda(lambda x: K.tf.stack(x, 1))(KM)

out_ = Dense(2, activation='softmax', kernel_initializer=RandomUniform(minval=-0.014, maxval=0.014), bias_initializer='zeros')(Phi)

model = Model(inputs=[query, doc], outputs=out_)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# query (InputLayer)              (None, 20)           0
# __________________________________________________________________________________________________
# doc (InputLayer)                (None, 20)           0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 20, 300)      25293600    query[0][0]
#                                                                  doc[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 20, 64)       19264       embedding_4[0][0]
#                                                                  embedding_4[1][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 20, 64)       38464       embedding_4[0][0]
#                                                                  embedding_4[1][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 20, 64)       57664       embedding_4[0][0]
#                                                                  embedding_4[1][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 20, 20)       0           conv1d_10[0][0]
#                                                                  conv1d_10[1][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 20, 20)       0           conv1d_10[0][0]
#                                                                  conv1d_11[1][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 20, 20)       0           conv1d_10[0][0]
#                                                                  conv1d_12[1][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 20, 20)       0           conv1d_11[0][0]
#                                                                  conv1d_10[1][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 20, 20)       0           conv1d_11[0][0]
#                                                                  conv1d_11[1][0]
# __________________________________________________________________________________________________
# dot_8 (Dot)                     (None, 20, 20)       0           conv1d_11[0][0]
#                                                                  conv1d_12[1][0]
# __________________________________________________________________________________________________
# dot_9 (Dot)                     (None, 20, 20)       0           conv1d_12[0][0]
#                                                                  conv1d_10[1][0]
# __________________________________________________________________________________________________
# dot_10 (Dot)                    (None, 20, 20)       0           conv1d_12[0][0]
#                                                                  conv1d_11[1][0]
# __________________________________________________________________________________________________
# dot_11 (Dot)                    (None, 20, 20)       0           conv1d_12[0][0]
#                                                                  conv1d_12[1][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 20, 20)       0           dot_3[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 20, 20)       0           dot_4[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_320 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_322 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_324 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_326 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_328 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_330 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_332 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_348 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_350 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_352 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_354 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_378 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_380 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_382 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, 20, 20)       0           dot_5[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_392 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_398 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_400 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_402 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_404 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_408 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_410 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_412 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_414 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_416 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_418 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_420 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_422 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_424 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_426 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_428 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_430 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_432 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_434 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_436 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# activation_438 (Activation)     (None, 20, 20)       0           dot_6[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  lambda_842[0][0]
#                                                                  lambda_844[0][0]
#                                                                  lambda_846[0][0]
#                                                                  lambda_848[0][0]
#                                                                  lambda_850[0][0]
#                                                                  lambda_852[0][0]
#                                                                  lambda_854[0][0]
#                                                                  lambda_856[0][0]
#                                                                  lambda_858[0][0]
#                                                                  lambda_860[0][0]
#                                                                  lambda_862[0][0]
#                                                                  lambda_864[0][0]
#                                                                  lambda_866[0][0]
#                                                                  lambda_868[0][0]
#                                                                  lambda_870[0][0]
#                                                                  lambda_872[0][0]
#                                                                  lambda_874[0][0]
#                                                                  lambda_876[0][0]
#                                                                  lambda_878[0][0]
#                                                                  lambda_880[0][0]
#                                                                  lambda_882[0][0]
#                                                                  lambda_884[0][0]
#                                                                  lambda_886[0][0]
#                                                                  lambda_888[0][0]
#                                                                  lambda_890[0][0]
#                                                                  lambda_892[0][0]
#                                                                  lambda_894[0][0]
#                                                                  lambda_896[0][0]
#                                                                  lambda_898[0][0]
#                                                                  lambda_900[0][0]
#                                                                  lambda_902[0][0]
#                                                                  lambda_904[0][0]
#                                                                  lambda_906[0][0]
#                                                                  lambda_908[0][0]
#                                                                  lambda_910[0][0]
#                                                                  lambda_912[0][0]
#                                                                  lambda_914[0][0]
#                                                                  lambda_916[0][0]
#                                                                  lambda_918[0][0]
#                                                                  lambda_920[0][0]
#                                                                  lambda_922[0][0]
#                                                                  lambda_924[0][0]
#                                                                  lambda_926[0][0]
#                                                                  lambda_928[0][0]
#                                                                  lambda_930[0][0]
#                                                                  lambda_932[0][0]
#                                                                  lambda_934[0][0]
#                                                                  lambda_936[0][0]
#                                                                  lambda_938[0][0]
#                                                                  lambda_940[0][0]
#                                                                  lambda_942[0][0]
#                                                                  lambda_944[0][0]
#                                                                  lambda_946[0][0]
#                                                                  lambda_948[0][0]
#                                                                  lambda_950[0][0]
#                                                                  lambda_952[0][0]
#                                                                  lambda_954[0][0]
#                                                                  lambda_956[0][0]
#                                                                  lambda_958[0][0]
#                                                                  lambda_960[0][0]
#                                                                  lambda_962[0][0]
#                                                                  lambda_964[0][0]
#                                                                  lambda_966[0][0]
#                                                                  lambda_968[0][0]
#                                                                  lambda_970[0][0]
#                                                                  lambda_972[0][0]
#                                                                  lambda_974[0][0]
#                                                                  lambda_976[0][0]
#                                                                  lambda_978[0][0]
#                                                                  lambda_980[0][0]
#                                                                  lambda_982[0][0]
#                                                                  lambda_984[0][0]
#                                                                  lambda_986[0][0]
#                                                                  lambda_988[0][0]
#                                                                  lambda_990[0][0]
#                                                                  lambda_992[0][0]
#                                                                  lambda_994[0][0]
#                                                                  lambda_996[0][0]
#                                                                  lambda_998[0][0]
#                                                                  lambda_1000[0][0]
#                                                                  lambda_1002[0][0]
#                                                                  lambda_1004[0][0]
#                                                                  lambda_1006[0][0]
#                                                                  lambda_1008[0][0]
#                                                                  lambda_1010[0][0]
#                                                                  lambda_1012[0][0]
#                                                                  lambda_1014[0][0]
#                                                                  lambda_1016[0][0]
#                                                                  lambda_1018[0][0]
#                                                                  lambda_1020[0][0]
#                                                                  lambda_1022[0][0]
#                                                                  lambda_1024[0][0]
#                                                                  lambda_1026[0][0]
#                                                                  lambda_1028[0][0]
#                                                                  lambda_1030[0][0]
#                                                                  lambda_1032[0][0]
#                                                                  lambda_1034[0][0]
#                                                                  lambda_1036[0][0]
#                                                                  lambda_1038[0][0]
#                                                                  lambda_1040[0][0]
#                                                                  lambda_1042[0][0]
#                                                                  lambda_1044[0][0]
#                                                                  lambda_1046[0][0]
#                                                                  lambda_1048[0][0]
#                                                                  lambda_1050[0][0]
#                                                                  lambda_1052[0][0]
#                                                                  lambda_1054[0][0]
#                                                                  lambda_1056[0][0]
#                                                                  lambda_1058[0][0]
#                                                                  lambda_1060[0][0]
#                                                                  lambda_1062[0][0]
#                                                                  lambda_1064[0][0]
#                                                                  lambda_1066[0][0]
#                                                                  lambda_1068[0][0]
#                                                                  lambda_1070[0][0]
#                                                                  lambda_1072[0][0]
#                                                                  lambda_1074[0][0]
#                                                                  lambda_1076[0][0]
#                                                                  lambda_1078[0][0]
#                                                                  lambda_1080[0][0]
#                                                                  lambda_1082[0][0]
#                                                                  lambda_1084[0][0]
#                                                                  lambda_1086[0][0]
#                                                                  lambda_1088[0][0]
#                                                                  lambda_1090[0][0]
#                                                                  lambda_1092[0][0]
#                                                                  lambda_1094[0][0]
#                                                                  lambda_1096[0][0]
#                                                                  lambda_1098[0][0]
#                                                                  lambda_1100[0][0]
#                                                                  lambda_1102[0][0]
#                                                                  lambda_1104[0][0]
#                                                                  lambda_1106[0][0]
#                                                                  lambda_1108[0][0]
#                                                                  lambda_1110[0][0]
#                                                                  lambda_1112[0][0]
#                                                                  lambda_1114[0][0]
#                                                                  lambda_1116[0][0]
#                                                                  lambda_1118[0][0]
#                                                                  lambda_1120[0][0]
#                                                                  lambda_1122[0][0]
#                                                                  lambda_1124[0][0]
#                                                                  lambda_1126[0][0]
#                                                                  lambda_1128[0][0]
#                                                                  lambda_1130[0][0]
#                                                                  lambda_1132[0][0]
#                                                                  lambda_1134[0][0]
#                                                                  lambda_1136[0][0]
#                                                                  lambda_1138[0][0]
#                                                                  lambda_1140[0][0]
#                                                                  lambda_1142[0][0]
#                                                                  lambda_1144[0][0]
#                                                                  lambda_1146[0][0]
#                                                                  lambda_1148[0][0]
#                                                                  lambda_1150[0][0]
#                                                                  lambda_1152[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1154        lambda_1153[0][0]
# ==================================================================================================
# Total params: 25,410,146
# Trainable params: 116,546
# Non-trainable params: 25,293,600
# __________________________________________________________________________________________________

# %%
import datetime,time
from keras.optimizers import Adam

callback_list = [
    keras.callbacks.EarlyStopping(
        monitor='acc',
        patience=5
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=MODEL_PATH,
        monitor='val_acc',
        save_best_only=True
    )
]

adadelta=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
# model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['binary_accuracy'])
model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

print('Train...')

model.fit([x1_train, x2_train], y_train, epochs=100, batch_size=128, callbacks=callback_list, validation_data=([x1_valid, x2_valid], y_valid))
# Out:
# Train...
# Train on 323426 samples, validate on 40428 samples
# Epoch 1/100
# 323426/323426 [==============================] - 838s 3ms/step - loss: 0.5447 - acc: 0.7322 - val_loss: 0.4252 - val_acc: 0.7959
# Epoch 2/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.4592 - acc: 0.7833 - val_loss: 0.4072 - val_acc: 0.8116
# Epoch 3/100
# 323426/323426 [==============================] - 806s 2ms/step - loss: 0.4305 - acc: 0.8019 - val_loss: 0.4269 - val_acc: 0.8062
# Epoch 4/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.3995 - acc: 0.8182 - val_loss: 0.4099 - val_acc: 0.8169
# Epoch 5/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.3841 - acc: 0.8284 - val_loss: 0.4944 - val_acc: 0.7821
# Epoch 6/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.3642 - acc: 0.8394 - val_loss: 0.4077 - val_acc: 0.8233
# Epoch 7/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.3572 - acc: 0.8439 - val_loss: 0.4128 - val_acc: 0.8254
# Epoch 8/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.3378 - acc: 0.8532 - val_loss: 0.5646 - val_acc: 0.7775
# Epoch 9/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.3176 - acc: 0.8616 - val_loss: 0.4199 - val_acc: 0.8259
# Epoch 10/100
# 323426/323426 [==============================] - 806s 2ms/step - loss: 0.3145 - acc: 0.8649 - val_loss: 0.4411 - val_acc: 0.8286
# Epoch 11/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.3011 - acc: 0.8716 - val_loss: 0.5022 - val_acc: 0.8111
# Epoch 12/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.2924 - acc: 0.8754 - val_loss: 0.4737 - val_acc: 0.8236
# Epoch 13/100
# 323426/323426 [==============================] - 800s 2ms/step - loss: 0.2776 - acc: 0.8824 - val_loss: 0.4725 - val_acc: 0.8280
# Epoch 14/100
# 323426/323426 [==============================] - 792s 2ms/step - loss: 0.2688 - acc: 0.8870 - val_loss: 0.4782 - val_acc: 0.8268
# Epoch 15/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.2680 - acc: 0.8884 - val_loss: 0.4869 - val_acc: 0.8266
# Epoch 16/100
# 323426/323426 [==============================] - 787s 2ms/step - loss: 0.2600 - acc: 0.8922 - val_loss: 0.5084 - val_acc: 0.8260
# Epoch 17/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.2443 - acc: 0.8995 - val_loss: 0.5131 - val_acc: 0.8256
# Epoch 18/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.2436 - acc: 0.8985 - val_loss: 0.6301 - val_acc: 0.8057
# Epoch 19/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.2328 - acc: 0.9040 - val_loss: 0.5598 - val_acc: 0.8176
# Epoch 20/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.2276 - acc: 0.9063 - val_loss: 0.5339 - val_acc: 0.8284
# Epoch 21/100
# 323426/323426 [==============================] - 798s 2ms/step - loss: 0.2226 - acc: 0.9082 - val_loss: 0.6745 - val_acc: 0.7994
# Epoch 22/100
# 323426/323426 [==============================] - 799s 2ms/step - loss: 0.2217 - acc: 0.9098 - val_loss: 0.5703 - val_acc: 0.8232
# Epoch 23/100
# 323426/323426 [==============================] - 799s 2ms/step - loss: 0.2111 - acc: 0.9140 - val_loss: 0.5724 - val_acc: 0.8264
# Epoch 24/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.2064 - acc: 0.9168 - val_loss: 0.6781 - val_acc: 0.8112
# Epoch 25/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.2030 - acc: 0.9178 - val_loss: 0.6052 - val_acc: 0.8267
# Epoch 26/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1992 - acc: 0.9200 - val_loss: 0.6465 - val_acc: 0.8185
# Epoch 27/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1908 - acc: 0.9234 - val_loss: 0.6237 - val_acc: 0.8261
# Epoch 28/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1909 - acc: 0.9233 - val_loss: 0.7629 - val_acc: 0.8012
# Epoch 29/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1883 - acc: 0.9252 - val_loss: 0.6850 - val_acc: 0.8239
# Epoch 30/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1857 - acc: 0.9262 - val_loss: 0.6792 - val_acc: 0.8252
# Epoch 31/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1745 - acc: 0.9309 - val_loss: 0.6909 - val_acc: 0.8261
# Epoch 32/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1789 - acc: 0.9297 - val_loss: 0.7266 - val_acc: 0.8236
# Epoch 33/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1701 - acc: 0.9322 - val_loss: 0.9158 - val_acc: 0.7881
# Epoch 34/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1658 - acc: 0.9338 - val_loss: 0.7148 - val_acc: 0.8248
# Epoch 35/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1630 - acc: 0.9351 - val_loss: 0.7280 - val_acc: 0.8245
# Epoch 36/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1615 - acc: 0.9357 - val_loss: 0.8023 - val_acc: 0.8166
# Epoch 37/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1597 - acc: 0.9372 - val_loss: 0.7636 - val_acc: 0.8228
# Epoch 38/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1596 - acc: 0.9372 - val_loss: 0.8039 - val_acc: 0.8170
# Epoch 39/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1543 - acc: 0.9395 - val_loss: 0.8156 - val_acc: 0.8246
# Epoch 40/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1483 - acc: 0.9417 - val_loss: 0.7894 - val_acc: 0.8225
# Epoch 41/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1535 - acc: 0.9398 - val_loss: 0.8130 - val_acc: 0.8224
# Epoch 42/100
# 323426/323426 [==============================] - 800s 2ms/step - loss: 0.1488 - acc: 0.9421 - val_loss: 0.8815 - val_acc: 0.8090
# Epoch 43/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1485 - acc: 0.9425 - val_loss: 0.8564 - val_acc: 0.8182
# Epoch 44/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1491 - acc: 0.9426 - val_loss: 0.8462 - val_acc: 0.8231
# Epoch 45/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1430 - acc: 0.9451 - val_loss: 0.8571 - val_acc: 0.8212
# Epoch 46/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1407 - acc: 0.9462 - val_loss: 0.8798 - val_acc: 0.8222
# Epoch 47/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1359 - acc: 0.9481 - val_loss: 0.8797 - val_acc: 0.8201
# Epoch 48/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1338 - acc: 0.9487 - val_loss: 0.9434 - val_acc: 0.8111
# Epoch 49/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1323 - acc: 0.9494 - val_loss: 0.8970 - val_acc: 0.8217
# Epoch 50/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1273 - acc: 0.9509 - val_loss: 0.9133 - val_acc: 0.8199
# Epoch 51/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1282 - acc: 0.9509 - val_loss: 0.9012 - val_acc: 0.8205
# Epoch 52/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1330 - acc: 0.9500 - val_loss: 0.9437 - val_acc: 0.8216
# Epoch 53/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1245 - acc: 0.9525 - val_loss: 0.9498 - val_acc: 0.8200
# Epoch 54/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1278 - acc: 0.9515 - val_loss: 0.9525 - val_acc: 0.8207
# Epoch 55/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.1264 - acc: 0.9520 - val_loss: 1.0387 - val_acc: 0.8161
# Epoch 56/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1237 - acc: 0.9536 - val_loss: 0.9778 - val_acc: 0.8212
# Epoch 57/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1225 - acc: 0.9540 - val_loss: 1.0005 - val_acc: 0.8213
# Epoch 58/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1215 - acc: 0.9547 - val_loss: 1.0216 - val_acc: 0.8147
# Epoch 59/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1173 - acc: 0.9559 - val_loss: 1.0038 - val_acc: 0.8208
# Epoch 60/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1186 - acc: 0.9557 - val_loss: 1.0369 - val_acc: 0.8181
# Epoch 61/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1173 - acc: 0.9564 - val_loss: 1.0448 - val_acc: 0.8192
# Epoch 62/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1127 - acc: 0.9577 - val_loss: 1.0293 - val_acc: 0.8214
# Epoch 63/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1170 - acc: 0.9571 - val_loss: 1.0408 - val_acc: 0.8204
# Epoch 64/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1127 - acc: 0.9580 - val_loss: 1.0548 - val_acc: 0.8196
# Epoch 65/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1087 - acc: 0.9591 - val_loss: 1.0820 - val_acc: 0.8200
# Epoch 66/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.1104 - acc: 0.9590 - val_loss: 1.0773 - val_acc: 0.8186
# Epoch 67/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.1108 - acc: 0.9592 - val_loss: 1.1051 - val_acc: 0.8198
# Epoch 68/100
# 323426/323426 [==============================] - 806s 2ms/step - loss: 0.1044 - acc: 0.9611 - val_loss: 1.1374 - val_acc: 0.8159
# Epoch 69/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1063 - acc: 0.9606 - val_loss: 1.1550 - val_acc: 0.8158
# Epoch 70/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.1051 - acc: 0.9610 - val_loss: 1.1190 - val_acc: 0.8164
# Epoch 71/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.1051 - acc: 0.9614 - val_loss: 1.1131 - val_acc: 0.8200
# Epoch 72/100
# 323426/323426 [==============================] - 801s 2ms/step - loss: 0.1048 - acc: 0.9618 - val_loss: 1.1140 - val_acc: 0.8202
# Epoch 73/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.0969 - acc: 0.9638 - val_loss: 1.1351 - val_acc: 0.8223
# Epoch 74/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.1023 - acc: 0.9624 - val_loss: 1.1315 - val_acc: 0.8224
# Epoch 75/100
# 323426/323426 [==============================] - 800s 2ms/step - loss: 0.1000 - acc: 0.9634 - val_loss: 1.1407 - val_acc: 0.8210
# Epoch 76/100
# 323426/323426 [==============================] - 799s 2ms/step - loss: 0.0965 - acc: 0.9647 - val_loss: 1.1573 - val_acc: 0.8192
# Epoch 77/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.0969 - acc: 0.9647 - val_loss: 1.1775 - val_acc: 0.8168
# Epoch 78/100
# 323426/323426 [==============================] - 800s 2ms/step - loss: 0.0986 - acc: 0.9645 - val_loss: 1.1687 - val_acc: 0.8202
# Epoch 79/100
# 323426/323426 [==============================] - 798s 2ms/step - loss: 0.0902 - acc: 0.9667 - val_loss: 1.1808 - val_acc: 0.8191
# Epoch 80/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.1004 - acc: 0.9642 - val_loss: 1.4073 - val_acc: 0.7958
# Epoch 81/100
# 323426/323426 [==============================] - 799s 2ms/step - loss: 0.0899 - acc: 0.9674 - val_loss: 1.2410 - val_acc: 0.8140
# Epoch 82/100
# 323426/323426 [==============================] - 806s 2ms/step - loss: 0.0943 - acc: 0.9656 - val_loss: 1.2179 - val_acc: 0.8170
# Epoch 83/100
# 323426/323426 [==============================] - 802s 2ms/step - loss: 0.0961 - acc: 0.9655 - val_loss: 1.2106 - val_acc: 0.8200
# Epoch 84/100
# 323426/323426 [==============================] - 808s 2ms/step - loss: 0.0870 - acc: 0.9681 - val_loss: 1.2122 - val_acc: 0.8195
# Epoch 85/100
# 323426/323426 [==============================] - 805s 2ms/step - loss: 0.0870 - acc: 0.9684 - val_loss: 1.2268 - val_acc: 0.8207
# Epoch 86/100
# 323426/323426 [==============================] - 806s 2ms/step - loss: 0.0866 - acc: 0.9685 - val_loss: 1.2375 - val_acc: 0.8183
# Epoch 87/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.0901 - acc: 0.9675 - val_loss: 1.2704 - val_acc: 0.8168
# Epoch 88/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.0893 - acc: 0.9679 - val_loss: 1.2867 - val_acc: 0.8177
# Epoch 89/100
# 323426/323426 [==============================] - 804s 2ms/step - loss: 0.0842 - acc: 0.9692 - val_loss: 1.3583 - val_acc: 0.8081
# Epoch 90/100
# 323426/323426 [==============================] - 798s 2ms/step - loss: 0.0857 - acc: 0.9688 - val_loss: 1.2859 - val_acc: 0.8179
# Epoch 91/100
# 323426/323426 [==============================] - 803s 2ms/step - loss: 0.0840 - acc: 0.9698 - val_loss: 1.3128 - val_acc: 0.8154
# Epoch 92/100
# 323426/323426 [==============================] - 781s 2ms/step - loss: 0.0865 - acc: 0.9690 - val_loss: 1.3009 - val_acc: 0.8184
# Epoch 93/100
# 323426/323426 [==============================] - 751s 2ms/step - loss: 0.0809 - acc: 0.9707 - val_loss: 1.4290 - val_acc: 0.8025
# Epoch 94/100
# 323426/323426 [==============================] - 751s 2ms/step - loss: 0.0818 - acc: 0.9706 - val_loss: 1.3133 - val_acc: 0.8160
# Epoch 95/100
# 323426/323426 [==============================] - 748s 2ms/step - loss: 0.0799 - acc: 0.9710 - val_loss: 1.3308 - val_acc: 0.8168
# Epoch 96/100
# 323426/323426 [==============================] - 769s 2ms/step - loss: 0.0834 - acc: 0.9706 - val_loss: 1.3611 - val_acc: 0.8144
# Epoch 97/100
# 323426/323426 [==============================] - 782s 2ms/step - loss: 0.0816 - acc: 0.9706 - val_loss: 1.3289 - val_acc: 0.8188
# Epoch 98/100
# 323426/323426 [==============================] - 797s 2ms/step - loss: 0.0870 - acc: 0.9694 - val_loss: 1.7263 - val_acc: 0.7828
# Epoch 99/100
# 323426/323426 [==============================] - 800s 2ms/step - loss: 0.0799 - acc: 0.9717 - val_loss: 1.3782 - val_acc: 0.8143
# Epoch 100/100
# 323426/323426 [==============================] - 782s 2ms/step - loss: 0.0762 - acc: 0.9730 - val_loss: 1.3433 - val_acc: 0.8178

# %%
y_vec_pred = model.predict([x1_test, x2_test], batch_size=128)

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support

def to_one_hot(prob):
    prob_shape = prob.shape
    y_pred = np.zeros(prob_shape)
    
    i = 0
    for item in prob:
        if item[0] < item[1]:
            y_pred[i] = np.array([0, 1])
        else:
            y_pred[i] = np.array([1, 0])
        i += 1
    return y_pred

y_pred = to_one_hot(y_vec_pred)
print(y_pred)
# Out:
# [[1. 0.]
#  [1. 0.]
#  [1. 0.]
#  ...
#  [1. 0.]
#  [0. 1.]
#  [1. 0.]]

# %%
report = precision_recall_fscore_support(y_test, y_pred, average='macro')
    
def print_prf(result):
    precision = str(round(result[0] * 100, 2)) + "%"
    recall = str(round(result[1] * 100, 2)) + "%"
    f1 = str(round(result[2] * 100, 2)) + "%"
    
    strResult="Precision:"+precision+"\tRecall:"+recall+"\tF-score:"+f1
    print(strResult)
    
print_prf(report)
# Out:
# Precision:79.93%	Recall:80.25%	F-score:80.08%

# %%
model.evaluate([x1_test, x2_test], y_test)
# Out:
# 40429/40429 [==============================] - 70s 2ms/step
# [1.4226651384583588, 0.8129807811268845]
